# %%
# Install dependencies
# !uv add anthropic python-dotenv
# Out:
# Resolved 55 packages in 16ms
# Audited 51 packages in 10ms

# %%
# Load env variable
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-5"

# print(client.models.list())

# %%
from anthropic.types import MessageParam
from rich import print

def add_user_message(messages: list[MessageParam], text: str) -> None:
    user_message = MessageParam({"role": "user", "content": text})
    messages.append(user_message)

def add_assistant_message(messages: list[MessageParam], text: str) -> None:
    assistant_message = MessageParam({"role": "assistant", "content": text})
    messages.append(assistant_message)

def chat(messages: list[MessageParam]) -> str:
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages
    )

    # print(message)

    return message.content[0].text

# %%
# Make a starting list of messages
messages: list[MessageParam] = []

# Add the initial user question
add_user_message(messages, "Define quantum computing in one message")

# Pass the list of messages into 'chat' to get an answer
answer = chat(messages)
print(answer)

# Take the answer and add it as an assistant message into our list
add_assistant_message(messages, answer)

# Add in the user's follow-up questions
add_user_message(messages, "Write another sentence")

# Call chat again with the list of messages to get a final answer
answer = chat(messages)
print(answer)
# Out:
# # Quantum Computing in a Nutshell
#
# **Quantum computing** is a type of computation that uses quantum mechanical phenomena—like **superposition**,
# **entanglement**, and **interference**—to process information in fundamentally different ways than classical
# computers.
#
# ## Key Concepts
#
# - **Qubits vs Bits**: Classical computers use bits (0 or 1). Quantum computers use **qubits**, which can exist in a
# superposition of both 0 and 1 simultaneously.
#
# - **Superposition**: A qubit can represent multiple states at once, allowing quantum computers to process many
# possibilities in parallel.
#
# - **Entanglement**: Qubits can become correlated in ways that have no classical equivalent—measuring one instantly
# affects the state of another, regardless of distance.
#
# - **Interference**: Quantum algorithms manipulate probability waves so that correct answers amplify and wrong
# answers cancel out.
#
# ## Why It Matters
#
# For certain problems—like factoring large numbers (Shor's algorithm), searching unsorted databases (Grover's
# algorithm), simulating molecules, and optimization—quantum computers could vastly outperform classical computers.
#
# ## Current Reality
#
# Quantum computers are still experimental, error-prone, and limited in scale (the "NISQ" era—Noisy
# Intermediate-Scale Quantum). They aren't a replacement for classical computers but a powerful complement for
# specific, complex problems.
# Despite these challenges, companies like IBM, Google, and startups worldwide are racing to achieve **quantum
# advantage**—the point where quantum computers solve real-world problems faster or more efficiently than the best
# classical supercomputers.
