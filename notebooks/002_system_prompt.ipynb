# %%
# Install dependencies
# !uv add anthropic python-dotenv

# %%
# Load env variable
from dotenv import load_dotenv

load_dotenv()

# %%
from utils.chat import chat, add_user_message, add_assistant_message
from anthropic.types import MessageParam

# !uv add rich
from rich import print

system = '''
You are a patient math tutor.
Do not provide direct answers to questions.
Guide your student step by step to the solution, in a clear, consise and precise way.
When the problem is solved just say [DONE].
'''

messages: list[MessageParam] = []

while True:
    user_message = input()
    print(f"user: {user_message}")

    add_user_message(messages, user_message)

    assistant_message = chat(messages, system=system, temperature=0.0)
    print(f"assistant: {assistant_message}")

    if "[DONE]" in assistant_message:
        break

    add_assistant_message(messages, assistant_message)

# %%
from utils.chat import chat, add_user_message, add_assistant_message
from anthropic.types import MessageParam

# !uv add rich
from rich import print

system = '''
You are a Python expert SWE who writes clear, idiomatic and very concise code.
'''

messages: list[MessageParam] = []

add_user_message(messages, "Write a Python function that returns duplicate characters from a string. In case of no duplicates, return empty sequence")

answer = chat(messages, system=system)
print(answer)
# Out:
# Resolved 55 packages in 15ms
# Audited 51 packages in 7ms
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[1], line 15
#      11 messages: list[MessageParam] = []
#      12
#      13 add_user_message(messages, "Write a Python function that returns duplicate characters from a string. In case of no duplicates, return empty sequence")
#      14
# ---> 15 answer = chat(messages, system=system, temperature=0.0)
#      16 print(answer)
#
# File ~/Learning/anthropic-course/notebooks/utils/chat.py:22, in chat(messages, model, max_tokens, temperature, system)
#      15 def chat(
#      16     messages: list[MessageParam],
#      17     model: str = "claude-sonnet-5",
#    (...)     20     system: str | Omit = omit,
#      21 ) -> str:
# ---> 22     message = client.messages.create(
#      23         model=model,
#      24         max_tokens=max_tokens,
# ...
